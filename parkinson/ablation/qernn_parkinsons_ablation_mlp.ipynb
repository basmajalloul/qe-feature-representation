# %%
import pandas as pd

# Load full quantum features
df = pd.read_csv("quantum_raw_parkinsons_gait_percent.csv")

print(f"✅ Loaded full quantum features: {df.shape[1]} columns.")
# Out:
# ✅ Loaded full quantum features: 12 columns.

# %%
import matplotlib.pyplot as plt

def plot_history(history, title):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    # Accuracy Plot
    axs[0].plot(history.history['accuracy'], label="Train Accuracy")
    axs[0].plot(history.history['val_accuracy'], label="Validation Accuracy")
    axs[0].set_title(f"Model Accuracy - {title}")
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend()

    # Loss Plot
    axs[1].plot(history.history['loss'], label="Train Loss")
    axs[1].plot(history.history['val_loss'], label="Validation Loss")
    axs[1].set_title(f"Model Loss - {title}")
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")
    axs[1].legend()

    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = df.drop(columns=["Subject_ID"])
df_corr = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature-Label Correlation")
plt.show()

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.layers import BatchNormalization, Dropout

tf.keras.backend.set_floatx('float32')

# Ensure features and labels are correctly extracted
X = df.drop(columns=["label"]).values  # Features
y = df["label"].values  # Labels

# Convert labels to one-hot encoding *before* splitting
y_onehot = tf.keras.utils.to_categorical(y, num_classes=2)

# Split once: train + temp
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y_onehot, random_state=42)

# Split again: train + val (from temp)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42)

# ✅ Remove MinMaxScaler, keep StandardScaler
scaler = StandardScaler()  # StandardScaler ensures proper feature scaling for PCA
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# Convert to float32 (required for TensorFlow)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
y_train = y_train.astype("float32")
X_val = X_val.astype("float32")

print(f"✅ X_train Labels shape: {y_train.shape}, {y_train.shape}")
print(f"✅ X_val Labels shape: {y_val.shape}, {y_val.shape}")
print(f"✅ X_test Labels shape: {y_test.shape}, {y_test.shape}")
# Out:
# ✅ X_train Labels shape: (2908,), (2908,)
# ✅ X_val Labels shape: (970,), (970,)
# ✅ X_test Labels shape: (970,), (970,)

# %%
import tensorflow as tf
import numpy as np

# Ensure input shape is flat: [samples, features]
assert len(X_train.shape) == 2, "Input should be flat [samples, features] for MLP"

# MLP model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
])

# Compile
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss="binary_crossentropy",
              metrics=["accuracy"])

# Convert labels to 1D if needed
if len(y_train.shape) > 1 and y_train.shape[1] > 1:
    y_train = np.argmax(y_train, axis=1)
    y_val = np.argmax(y_val, axis=1)

# Train
history = model.fit(X_train, y_train,
                    epochs=20,
                    validation_data=(X_val, y_val),
                    batch_size=32,
                    verbose=1)
# Out:
# Epoch 1/20
# 91/91 [==============================] - 3s 8ms/step - loss: 0.6929 - accuracy: 0.4622 - val_loss: 0.6661 - val_accuracy: 0.4330
# Epoch 2/20
# 91/91 [==============================] - 0s 5ms/step - loss: 0.6563 - accuracy: 0.5660 - val_loss: 0.6292 - val_accuracy: 0.7814
# Epoch 3/20
# 91/91 [==============================] - 0s 5ms/step - loss: 0.6259 - accuracy: 0.6981 - val_loss: 0.5986 - val_accuracy: 0.8144
# Epoch 4/20
# 91/91 [==============================] - 1s 6ms/step - loss: 0.5971 - accuracy: 0.7669 - val_loss: 0.5662 - val_accuracy: 0.8227
# Epoch 5/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.5675 - accuracy: 0.7992 - val_loss: 0.5314 - val_accuracy: 0.8340
# Epoch 6/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.5352 - accuracy: 0.8091 - val_loss: 0.4935 - val_accuracy: 0.8412
# Epoch 7/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.5027 - accuracy: 0.8136 - val_loss: 0.4549 - val_accuracy: 0.8474
# Epoch 8/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.4685 - accuracy: 0.8281 - val_loss: 0.4177 - val_accuracy: 0.8546
# Epoch 9/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.4318 - accuracy: 0.8418 - val_loss: 0.3829 - val_accuracy: 0.8619
# Epoch 10/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.4030 - accuracy: 0.8483 - val_loss: 0.3547 - val_accuracy: 0.8660
# Epoch 11/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3815 - accuracy: 0.8514 - val_loss: 0.3348 - val_accuracy: 0.8670
# Epoch 12/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3643 - accuracy: 0.8532 - val_loss: 0.3184 - val_accuracy: 0.8732
# Epoch 13/20
# 91/91 [==============================] - 0s 5ms/step - loss: 0.3546 - accuracy: 0.8508 - val_loss: 0.3071 - val_accuracy: 0.8742
# Epoch 14/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3440 - accuracy: 0.8545 - val_loss: 0.2990 - val_accuracy: 0.8763
# Epoch 15/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3330 - accuracy: 0.8673 - val_loss: 0.2934 - val_accuracy: 0.8763
# Epoch 16/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3305 - accuracy: 0.8583 - val_loss: 0.2877 - val_accuracy: 0.8866
# Epoch 17/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3288 - accuracy: 0.8635 - val_loss: 0.2846 - val_accuracy: 0.8856
# Epoch 18/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3182 - accuracy: 0.8638 - val_loss: 0.2821 - val_accuracy: 0.8825
# Epoch 19/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3183 - accuracy: 0.8676 - val_loss: 0.2796 - val_accuracy: 0.8876
# Epoch 20/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.3124 - accuracy: 0.8697 - val_loss: 0.2780 - val_accuracy: 0.8856

# %%
plot_history(history, "QNN Quantum+PCA Reduced Features")

# %%
# ✅ Evaluate
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"QNN Test Accuracy: {test_acc:.4f} | Loss: {test_loss:.4f}")
# Out:
# 31/31 [==============================] - 0s 3ms/step - loss: 0.3003 - accuracy: 0.8670
# QNN Test Accuracy: 0.8670 | Loss: 0.3003

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 🔹 Step 1: Get prediction probabilities
y_pred_probs = model.predict(X_test)

# 🔹 Step 2: Binarize predictions (assuming sigmoid output layer)
y_pred = (y_pred_probs > 0.5).astype(int).flatten()

# 🔹 Step 3: Decode true labels if they're one-hot encoded
if len(y_test.shape) > 1 and y_test.shape[1] > 1:
    y_test = np.argmax(y_test, axis=1)  # convert [0,1] to 1 and [1,0] to 0

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt=".0f", cmap="Blues",
            xticklabels=["Off", "On"], yticklabels=["Off", "On"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - QE-RNN Model")
plt.show()

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# 31/31 [==============================] - 0s 1ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87       465
#            1       0.91      0.82      0.87       505
#
#     accuracy                           0.87       970
#    macro avg       0.87      0.87      0.87       970
# weighted avg       0.87      0.87      0.87       970

# %% [markdown]
# # Confidence Check

# %%
import numpy as np

# Get model predictions
y_pred_probs = model.predict(X_test)

# Check confidence distribution
print("Min Confidence:", np.min(y_pred_probs))
print("Max Confidence:", np.max(y_pred_probs))
print("Mean Confidence:", np.mean(y_pred_probs))
# Out:
# 31/31 [==============================] - 0s 1ms/step
# Min Confidence: 0.062350452
# Max Confidence: 1.0
# Mean Confidence: 0.51126635

# %%
y_true_qnn = y_test# Convert one-hot labels to class labels
y_pred_qnn = np.argmax(model.predict(X_test), axis=1)
confidences_qnn = np.max(model.predict(X_test), axis=1)

# Convert to numpy arrays if needed
qnn_confidences = np.array(confidences_qnn)  # Replace with your QNN confidence list

plt.figure(figsize=(10, 5))

# QNN Confidence Distribution
plt.subplot(1, 2, 1)
plt.hist(qnn_confidences, bins=20, color='blue', alpha=0.7, edgecolor='black')
plt.title("QNN Confidence Distribution")
plt.xlabel("Confidence Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
# Out:
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step

# %% [markdown]
# # K-Fold

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# Define number of folds
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Store metrics
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []

all_train_acc = []
all_val_acc = []
all_train_loss = []
all_val_loss = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
    print(f"\nTraining Fold {fold+1}/{k}")

    # Split data
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # Define MLP model
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, clipvalue=0.5),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])

    # Train model
    history = model.fit(X_train_fold, y_train_fold, 
                        epochs=20, batch_size=32, 
                        validation_data=(X_val_fold, y_val_fold), 
                        verbose=1)

    # Store per-epoch results
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])

    # Evaluate model
    _, accuracy = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    print(f"Fold {fold+1} Accuracy: {accuracy:.4f}")

# Optionally compute average metrics across folds (last epoch)
final_train_acc = [acc[-1] for acc in train_accuracies]
final_val_acc = [acc[-1] for acc in val_accuracies]
final_train_loss = [loss[-1] for loss in train_losses]
final_val_loss = [loss[-1] for loss in val_losses]

print("\n📊 Final K-Fold Results (MLP on Quantum Features):")
print(f"Train Accuracy: {np.mean(final_train_acc):.4f} ± {np.std(final_train_acc):.4f}")
print(f"Val Accuracy:   {np.mean(final_val_acc):.4f} ± {np.std(final_val_acc):.4f}")
print(f"Train Loss:     {np.mean(final_train_loss):.4f} ± {np.std(final_train_loss):.4f}")
print(f"Val Loss:       {np.mean(final_val_loss):.4f} ± {np.std(final_val_loss):.4f}")
# Out:
# Training Fold 1/5
# Epoch 1/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6673 - accuracy: 0.5262 - val_loss: 0.6579 - val_accuracy: 0.4931
# Epoch 2/20
# 73/73 [==============================] - 1s 7ms/step - loss: 0.6421 - accuracy: 0.5464 - val_loss: 0.6318 - val_accuracy: 0.4931
# Epoch 3/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6189 - accuracy: 0.6015 - val_loss: 0.6028 - val_accuracy: 0.8883
# Epoch 4/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5922 - accuracy: 0.7107 - val_loss: 0.5710 - val_accuracy: 0.8763
# Epoch 5/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5639 - accuracy: 0.7966 - val_loss: 0.5306 - val_accuracy: 0.8746
# Epoch 6/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5283 - accuracy: 0.8177 - val_loss: 0.4883 - val_accuracy: 0.8625
# Epoch 7/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4925 - accuracy: 0.8263 - val_loss: 0.4487 - val_accuracy: 0.8643
# Epoch 8/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4615 - accuracy: 0.8375 - val_loss: 0.4117 - val_accuracy: 0.8677
# Epoch 9/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4316 - accuracy: 0.8482 - val_loss: 0.3791 - val_accuracy: 0.8780
# Epoch 10/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4100 - accuracy: 0.8332 - val_loss: 0.3508 - val_accuracy: 0.8832
# Epoch 11/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3843 - accuracy: 0.8444 - val_loss: 0.3279 - val_accuracy: 0.8849
# Epoch 12/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8512 - val_loss: 0.3107 - val_accuracy: 0.8883
# Epoch 13/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3583 - accuracy: 0.8521 - val_loss: 0.2966 - val_accuracy: 0.8918
# Epoch 14/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3460 - accuracy: 0.8547 - val_loss: 0.2858 - val_accuracy: 0.8935
# Epoch 15/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3385 - accuracy: 0.8594 - val_loss: 0.2782 - val_accuracy: 0.8986
# Epoch 16/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.3369 - accuracy: 0.8590 - val_loss: 0.2719 - val_accuracy: 0.8986
# Epoch 17/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3315 - accuracy: 0.8530 - val_loss: 0.2669 - val_accuracy: 0.8969
# Epoch 18/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3326 - accuracy: 0.8530 - val_loss: 0.2629 - val_accuracy: 0.9003
# Epoch 19/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.3253 - accuracy: 0.8560 - val_loss: 0.2597 - val_accuracy: 0.9003
# Epoch 20/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.3230 - accuracy: 0.8594 - val_loss: 0.2571 - val_accuracy: 0.9003
# Fold 1 Accuracy: 0.9003
#
# Training Fold 2/5
# Epoch 1/20
# 73/73 [==============================] - 1s 6ms/step - loss: 0.6627 - accuracy: 0.6406 - val_loss: 0.6475 - val_accuracy: 0.7904
# Epoch 2/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6326 - accuracy: 0.7270 - val_loss: 0.6193 - val_accuracy: 0.8196
# Epoch 3/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6107 - accuracy: 0.7588 - val_loss: 0.5916 - val_accuracy: 0.8265
# Epoch 4/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5864 - accuracy: 0.7833 - val_loss: 0.5620 - val_accuracy: 0.8299
# Epoch 5/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5586 - accuracy: 0.7902 - val_loss: 0.5306 - val_accuracy: 0.8454
# Epoch 6/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.5303 - accuracy: 0.8169 - val_loss: 0.4975 - val_accuracy: 0.8591
# Epoch 7/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5012 - accuracy: 0.8246 - val_loss: 0.4661 - val_accuracy: 0.8677
# Epoch 8/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4713 - accuracy: 0.8371 - val_loss: 0.4363 - val_accuracy: 0.8591
# Epoch 9/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4503 - accuracy: 0.8388 - val_loss: 0.4083 - val_accuracy: 0.8643
# Epoch 10/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4235 - accuracy: 0.8478 - val_loss: 0.3820 - val_accuracy: 0.8746
# Epoch 11/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4023 - accuracy: 0.8500 - val_loss: 0.3596 - val_accuracy: 0.8780
# Epoch 12/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.3872 - accuracy: 0.8495 - val_loss: 0.3417 - val_accuracy: 0.8849
# Epoch 13/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.3727 - accuracy: 0.8551 - val_loss: 0.3269 - val_accuracy: 0.8849
# Epoch 14/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3585 - accuracy: 0.8564 - val_loss: 0.3152 - val_accuracy: 0.8918
# Epoch 15/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3568 - accuracy: 0.8508 - val_loss: 0.3057 - val_accuracy: 0.8969
# Epoch 16/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3476 - accuracy: 0.8538 - val_loss: 0.2978 - val_accuracy: 0.8918
# Epoch 17/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3429 - accuracy: 0.8491 - val_loss: 0.2915 - val_accuracy: 0.8918
# Epoch 18/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3314 - accuracy: 0.8581 - val_loss: 0.2866 - val_accuracy: 0.8935
# Epoch 19/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3266 - accuracy: 0.8616 - val_loss: 0.2826 - val_accuracy: 0.8935
# Epoch 20/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3290 - accuracy: 0.8590 - val_loss: 0.2795 - val_accuracy: 0.8969
# Fold 2 Accuracy: 0.8969
#
# Training Fold 3/5
# Epoch 1/20
# 73/73 [==============================] - 1s 5ms/step - loss: 0.6535 - accuracy: 0.6062 - val_loss: 0.6303 - val_accuracy: 0.8127
# Epoch 2/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6270 - accuracy: 0.7395 - val_loss: 0.5995 - val_accuracy: 0.7990
# Epoch 3/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5985 - accuracy: 0.7696 - val_loss: 0.5698 - val_accuracy: 0.7973
# Epoch 4/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.5672 - accuracy: 0.7893 - val_loss: 0.5386 - val_accuracy: 0.7955
# Epoch 5/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5403 - accuracy: 0.7954 - val_loss: 0.5056 - val_accuracy: 0.8041
# Epoch 6/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.5088 - accuracy: 0.8117 - val_loss: 0.4737 - val_accuracy: 0.8179
# Epoch 7/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4795 - accuracy: 0.8267 - val_loss: 0.4436 - val_accuracy: 0.8247
# Epoch 8/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4520 - accuracy: 0.8315 - val_loss: 0.4167 - val_accuracy: 0.8351
# Epoch 9/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4288 - accuracy: 0.8298 - val_loss: 0.3931 - val_accuracy: 0.8454
# Epoch 10/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4088 - accuracy: 0.8422 - val_loss: 0.3770 - val_accuracy: 0.8436
# Epoch 11/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3917 - accuracy: 0.8435 - val_loss: 0.3587 - val_accuracy: 0.8522
# Epoch 12/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3766 - accuracy: 0.8461 - val_loss: 0.3483 - val_accuracy: 0.8505
# Epoch 13/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3655 - accuracy: 0.8525 - val_loss: 0.3391 - val_accuracy: 0.8643
# Epoch 14/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3620 - accuracy: 0.8461 - val_loss: 0.3341 - val_accuracy: 0.8625
# Epoch 15/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3550 - accuracy: 0.8521 - val_loss: 0.3275 - val_accuracy: 0.8660
# Epoch 16/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3478 - accuracy: 0.8500 - val_loss: 0.3268 - val_accuracy: 0.8660
# Epoch 17/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3385 - accuracy: 0.8568 - val_loss: 0.3185 - val_accuracy: 0.8694
# Epoch 18/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3363 - accuracy: 0.8500 - val_loss: 0.3154 - val_accuracy: 0.8694
# Epoch 19/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3374 - accuracy: 0.8474 - val_loss: 0.3138 - val_accuracy: 0.8711
# Epoch 20/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3304 - accuracy: 0.8598 - val_loss: 0.3121 - val_accuracy: 0.8729
# Fold 3 Accuracy: 0.8729
#
# Training Fold 4/5
# Epoch 1/20
# 73/73 [==============================] - 1s 5ms/step - loss: 0.7161 - accuracy: 0.4942 - val_loss: 0.6876 - val_accuracy: 0.4905
# Epoch 2/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6872 - accuracy: 0.5685 - val_loss: 0.6613 - val_accuracy: 0.6713
# Epoch 3/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6612 - accuracy: 0.6532 - val_loss: 0.6388 - val_accuracy: 0.7177
# Epoch 4/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6358 - accuracy: 0.7129 - val_loss: 0.6134 - val_accuracy: 0.7453
# Epoch 5/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6118 - accuracy: 0.7456 - val_loss: 0.5851 - val_accuracy: 0.7590
# Epoch 6/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5859 - accuracy: 0.7658 - val_loss: 0.5581 - val_accuracy: 0.7728
# Epoch 7/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5607 - accuracy: 0.7740 - val_loss: 0.5313 - val_accuracy: 0.7711
# Epoch 8/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5374 - accuracy: 0.7907 - val_loss: 0.5053 - val_accuracy: 0.7728
# Epoch 9/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.8015 - val_loss: 0.4811 - val_accuracy: 0.7831
# Epoch 10/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4880 - accuracy: 0.8122 - val_loss: 0.4587 - val_accuracy: 0.7917
# Epoch 11/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4650 - accuracy: 0.8238 - val_loss: 0.4364 - val_accuracy: 0.8107
# Epoch 12/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4381 - accuracy: 0.8320 - val_loss: 0.4159 - val_accuracy: 0.8124
# Epoch 13/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4191 - accuracy: 0.8358 - val_loss: 0.3983 - val_accuracy: 0.8210
# Epoch 14/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4023 - accuracy: 0.8414 - val_loss: 0.3831 - val_accuracy: 0.8279
# Epoch 15/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3858 - accuracy: 0.8401 - val_loss: 0.3707 - val_accuracy: 0.8330
# Epoch 16/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3762 - accuracy: 0.8410 - val_loss: 0.3611 - val_accuracy: 0.8399
# Epoch 17/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3549 - accuracy: 0.8573 - val_loss: 0.3534 - val_accuracy: 0.8417
# Epoch 18/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3564 - accuracy: 0.8483 - val_loss: 0.3465 - val_accuracy: 0.8399
# Epoch 19/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3443 - accuracy: 0.8565 - val_loss: 0.3424 - val_accuracy: 0.8399
# Epoch 20/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3370 - accuracy: 0.8646 - val_loss: 0.3376 - val_accuracy: 0.8417
# Fold 4 Accuracy: 0.8417
#
# Training Fold 5/5
# Epoch 1/20
# 73/73 [==============================] - 1s 5ms/step - loss: 0.6836 - accuracy: 0.5432 - val_loss: 0.6656 - val_accuracy: 0.6609
# Epoch 2/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6603 - accuracy: 0.6790 - val_loss: 0.6426 - val_accuracy: 0.7797
# Epoch 3/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.6382 - accuracy: 0.7559 - val_loss: 0.6176 - val_accuracy: 0.7935
# Epoch 4/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6117 - accuracy: 0.7804 - val_loss: 0.5946 - val_accuracy: 0.7866
# Epoch 5/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.5908 - accuracy: 0.7830 - val_loss: 0.5718 - val_accuracy: 0.7849
# Epoch 6/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.5644 - accuracy: 0.7997 - val_loss: 0.5482 - val_accuracy: 0.7917
# Epoch 7/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.5399 - accuracy: 0.8101 - val_loss: 0.5238 - val_accuracy: 0.7952
# Epoch 8/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.5149 - accuracy: 0.8135 - val_loss: 0.4984 - val_accuracy: 0.7986
# Epoch 9/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4882 - accuracy: 0.8156 - val_loss: 0.4732 - val_accuracy: 0.8038
# Epoch 10/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4673 - accuracy: 0.8161 - val_loss: 0.4496 - val_accuracy: 0.8021
# Epoch 11/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4402 - accuracy: 0.8290 - val_loss: 0.4248 - val_accuracy: 0.8124
# Epoch 12/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4206 - accuracy: 0.8303 - val_loss: 0.4051 - val_accuracy: 0.8141
# Epoch 13/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.4052 - accuracy: 0.8367 - val_loss: 0.3853 - val_accuracy: 0.8279
# Epoch 14/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3896 - accuracy: 0.8388 - val_loss: 0.3742 - val_accuracy: 0.8279
# Epoch 15/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3814 - accuracy: 0.8393 - val_loss: 0.3604 - val_accuracy: 0.8434
# Epoch 16/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3673 - accuracy: 0.8526 - val_loss: 0.3517 - val_accuracy: 0.8434
# Epoch 17/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3569 - accuracy: 0.8513 - val_loss: 0.3423 - val_accuracy: 0.8468
# Epoch 18/20
# 73/73 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.8474 - val_loss: 0.3352 - val_accuracy: 0.8520
# Epoch 19/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3433 - accuracy: 0.8569 - val_loss: 0.3314 - val_accuracy: 0.8485
# Epoch 20/20
# 73/73 [==============================] - 0s 3ms/step - loss: 0.3309 - accuracy: 0.8659 - val_loss: 0.3267 - val_accuracy: 0.8554
# Fold 5 Accuracy: 0.8554
#
# 📊 Final K-Fold Results (MLP on Quantum Features):
# Train Accuracy: 0.8618 ± 0.0029
# Val Accuracy:   0.8734 ± 0.0228
# Train Loss:     0.3301 ± 0.0045
# Val Loss:       0.3026 ± 0.0300

# %%
# Convert lists to NumPy arrays for easy averaging
train_accuracies = np.array(train_accuracies)
val_accuracies = np.array(val_accuracies)
train_losses = np.array(train_losses)
val_losses = np.array(val_losses)

# Compute mean accuracy/loss across folds
mean_train_acc = np.mean(train_accuracies, axis=0)
mean_val_acc = np.mean(val_accuracies, axis=0)
mean_train_loss = np.mean(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)

# 🎯 Final mean accuracy across folds
final_accuracy = np.mean(val_accuracies[:, -1])
print(f"\nFinal K-Fold Accuracy: {final_accuracy:.4f}")

# 📊 Plot Accuracy Curves
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(mean_train_acc, label='Train Accuracy')
plt.plot(mean_val_acc, label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Parkinson's QE-RNN - Mean Accuracy Over Folds")
plt.legend()

# 📊 Plot Loss Curves
plt.subplot(1, 2, 2)
plt.plot(mean_train_loss, label='Train Loss')
plt.plot(mean_val_loss, label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Parkinson's QE-RNN - Mean Loss Over Folds")
plt.legend()

plt.show()
# Out:
# Final K-Fold Accuracy: 0.8734

# %%
import pandas as pd
import numpy as np

# Convert lists to numpy arrays
folds = list(range(1, len(train_accuracies) + 1))

# Create DataFrame with results per fold
df_results = pd.DataFrame({
    'Fold': folds,
    'Final Train Accuracy': [train_acc[-1] for train_acc in train_accuracies],
    'Final Validation Accuracy': [val_acc[-1] for val_acc in val_accuracies],
    'Final Train Loss': [train_loss[-1] for train_loss in train_losses],
    'Final Validation Loss': [val_loss[-1] for val_loss in val_losses]
})

# Print results
print("\n📊 K-Fold Cross-Validation Results:\n")
print(df_results)

# Compute summary statistics (mean & std deviation)
df_summary = df_results.describe().loc[['mean', 'std']]
print("\n📌 Summary Statistics (Mean & Std Deviation):\n")
print(df_summary)
# Out:
# 📊 K-Fold Cross-Validation Results:
#
#    Fold  Final Train Accuracy  Final Validation Accuracy  Final Train Loss  \
# 0     1              0.859415                   0.900344          0.323041
# 1     2              0.858985                   0.896907          0.328950
# 2     3              0.859845                   0.872852          0.330425
# 3     4              0.864633                   0.841652          0.337020
# 4     5              0.865922                   0.855422          0.330883
#
#    Final Validation Loss
# 0               0.257086
# 1               0.279498
# 2               0.312146
# 3               0.337645
# 4               0.326726
#
# 📌 Summary Statistics (Mean & Std Deviation):
#
#           Fold  Final Train Accuracy  Final Validation Accuracy  \
# mean  3.000000              0.861760                   0.873435
# std   1.581139              0.003257                   0.025544
#
#       Final Train Loss  Final Validation Loss
# mean          0.330064               0.302620
# std           0.004994               0.033566

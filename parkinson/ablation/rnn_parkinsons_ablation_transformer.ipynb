# %%
import pandas as pd

# Load full quantum features
df = pd.read_csv("../final_parkinsons_features.csv")

print(f"✅ Loaded full quantum features: {df.shape[1]} columns.")
# Out:
# ✅ Loaded full quantum features: 22 columns.

# %%
import matplotlib.pyplot as plt

def plot_history(history, title):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    # Accuracy Plot
    axs[0].plot(history.history['accuracy'], label="Train Accuracy")
    axs[0].plot(history.history['val_accuracy'], label="Validation Accuracy")
    axs[0].set_title(f"Model Accuracy - {title}")
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend()

    # Loss Plot
    axs[1].plot(history.history['loss'], label="Train Loss")
    axs[1].plot(history.history['val_loss'], label="Validation Loss")
    axs[1].set_title(f"Model Loss - {title}")
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")
    axs[1].legend()

    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = df.drop(columns=["Subject_ID","Gait_Cycle_Percent","Unnamed: 0"])
df_corr = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature-Label Correlation")
plt.show()

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.layers import BatchNormalization, Dropout

tf.keras.backend.set_floatx('float32')

# Ensure features and labels are correctly extracted
X = df.drop(columns=["label"]).values  # Features
y = df["label"].values  # Labels

# Convert labels to one-hot encoding *before* splitting
y_onehot = tf.keras.utils.to_categorical(y, num_classes=2)

# Split once: train + temp
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y_onehot, random_state=42)

# Split again: train + val (from temp)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42)

# ✅ Remove MinMaxScaler, keep StandardScaler
scaler = StandardScaler()  # StandardScaler ensures proper feature scaling for PCA
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# Convert to float32 (required for TensorFlow)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
y_train = y_train.astype("float32")
X_val = X_val.astype("float32")

print(f"✅ X_train Labels shape: {y_train.shape}, {y_train.shape}")
print(f"✅ X_val Labels shape: {y_val.shape}, {y_val.shape}")
print(f"✅ X_test Labels shape: {y_test.shape}, {y_test.shape}")
# Out:
# ✅ X_train Labels shape: (2908,), (2908,)
# ✅ X_val Labels shape: (970,), (970,)
# ✅ X_test Labels shape: (970,), (970,)

# %%
# Expand feature dimension for CNN/Transformer
X_train_seq = np.expand_dims(X_train, axis=-1)
X_val_seq   = np.expand_dims(X_val, axis=-1)
X_test_seq  = np.expand_dims(X_test, axis=-1)

print("Reshaped Transformer input:", X_train_seq.shape)  # (2908, 10, 1)
# Out:
# Reshaped Transformer input: (2908, 18, 1)

# %% [markdown]
# # Transformer Baseline

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers

def build_transformer_baseline(input_shape, embed_dim=32, num_heads=4, ff_dim=64, dropout=0.2):
    """
    input_shape: (steps, channels)  -> e.g., (10, 1)
    Treat each feature as a 'token' and project it to an embedding, then apply self-attention.
    """
    inputs = layers.Input(shape=input_shape)                   # (steps, 1)
    x = layers.Dense(embed_dim)(inputs)                        # (steps, embed_dim)

    # --- Encoder block 1 ---
    attn_out = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(x, x)
    x = layers.Add()([x, attn_out])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    ffn = tf.keras.Sequential([
        layers.Dense(ff_dim, activation="relu"),
        layers.Dense(embed_dim),
    ])
    ffn_out = ffn(x)
    x = layers.Add()([x, ffn_out])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.Dropout(dropout)(x)

    # --- Encoder block 2 (lightweight) ---
    attn_out = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(x, x)
    x = layers.Add()([x, attn_out])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    ffn_out = ffn(x)
    x = layers.Add()([x, ffn_out])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.Dropout(dropout)(x)

    # Pool + head
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(32, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer=optimizers.Adam(learning_rate=1e-4, clipvalue=0.5),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# --- Run Transformer baseline (mirrors your CNN calls) ---
transformer_model = build_transformer_baseline((X_train_seq.shape[1], X_train_seq.shape[2]))
history_transformer = transformer_model.fit(
    X_train_seq, y_train,
    validation_data=(X_val_seq, y_val),
    epochs=20,
    batch_size=32,
    verbose=1
)
transformer_results = transformer_model.evaluate(X_val_seq, y_val, verbose=0)
print(f"Transformer Baseline Validation Accuracy: {transformer_results[1]*100:.2f}%")
# Out:
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.5182 - loss: 0.7008 - val_accuracy: 0.5423 - val_loss: 0.6927
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5165 - loss: 0.6997 - val_accuracy: 0.5175 - val_loss: 0.6927
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5110 - loss: 0.6936 - val_accuracy: 0.5247 - val_loss: 0.6930
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5024 - loss: 0.6956 - val_accuracy: 0.5186 - val_loss: 0.6926
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5072 - loss: 0.6954 - val_accuracy: 0.5021 - val_loss: 0.6923
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5248 - loss: 0.6936 - val_accuracy: 0.5165 - val_loss: 0.6927
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5151 - loss: 0.6926 - val_accuracy: 0.5093 - val_loss: 0.6940
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4966 - loss: 0.6933 - val_accuracy: 0.5155 - val_loss: 0.6928
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5103 - loss: 0.6941 - val_accuracy: 0.5134 - val_loss: 0.6920
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5103 - loss: 0.6922 - val_accuracy: 0.5186 - val_loss: 0.6917
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5213 - loss: 0.6926 - val_accuracy: 0.5196 - val_loss: 0.6924
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5254 - loss: 0.6921 - val_accuracy: 0.5206 - val_loss: 0.6921
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5279 - loss: 0.6920 - val_accuracy: 0.5155 - val_loss: 0.6906
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5261 - loss: 0.6921 - val_accuracy: 0.5196 - val_loss: 0.6924
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5261 - loss: 0.6918 - val_accuracy: 0.5196 - val_loss: 0.6920
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5358 - loss: 0.6902 - val_accuracy: 0.5278 - val_loss: 0.6913
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5248 - loss: 0.6912 - val_accuracy: 0.5124 - val_loss: 0.6911
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5337 - loss: 0.6910 - val_accuracy: 0.5340 - val_loss: 0.6905
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5306 - loss: 0.6909 - val_accuracy: 0.5186 - val_loss: 0.6907
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5196 - loss: 0.6920 - val_accuracy: 0.5186 - val_loss: 0.6902
# Transformer Baseline Validation Accuracy: 51.86%

# %%
plot_history(history_transformer, "QNN Quantum+PCA Reduced Features")

# %%
# ✅ Evaluate
test_loss, test_acc = transformer_model.evaluate(X_test_seq, y_test)
print(f"QNN Test Accuracy: {test_acc:.4f} | Loss: {test_loss:.4f}")
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5268 - loss: 0.6894
# QNN Test Accuracy: 0.5268 | Loss: 0.6894

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 🔹 Step 1: Get prediction probabilities
y_pred_probs = transformer_model.predict(X_test)

# 🔹 Step 2: Binarize predictions (assuming sigmoid output layer)
y_pred = (y_pred_probs > 0.5).astype(int).flatten()

# 🔹 Step 3: Decode true labels if they're one-hot encoded
if len(y_test.shape) > 1 and y_test.shape[1] > 1:
    y_test = np.argmax(y_test, axis=1)  # convert [0,1] to 1 and [1,0] to 0

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt=".0f", cmap="Blues",
            xticklabels=["Off", "On"], yticklabels=["Off", "On"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - QE-RNN Model")
plt.show()

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.13      0.21       465
#            1       0.53      0.89      0.66       505
#
#     accuracy                           0.53       970
#    macro avg       0.53      0.51      0.44       970
# weighted avg       0.53      0.53      0.45       970

# %% [markdown]
# # Confidence Check

# %%
import numpy as np

# Get model predictions
y_pred_probs = transformer_model.predict(X_test)

# Check confidence distribution
print("Min Confidence:", np.min(y_pred_probs))
print("Max Confidence:", np.max(y_pred_probs))
print("Mean Confidence:", np.mean(y_pred_probs))
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Min Confidence: 0.45170978
# Max Confidence: 0.60247344
# Mean Confidence: 0.5216077

# %%
y_true_qnn = y_test# Convert one-hot labels to class labels
y_pred_qnn = np.argmax(transformer_model.predict(X_test), axis=1)
confidences_qnn = np.max(transformer_model.predict(X_test), axis=1)

# Convert to numpy arrays if needed
qnn_confidences = np.array(confidences_qnn)  # Replace with your QNN confidence list

plt.figure(figsize=(10, 5))

# QNN Confidence Distribution
plt.subplot(1, 2, 1)
plt.hist(qnn_confidences, bins=20, color='blue', alpha=0.7, edgecolor='black')
plt.title("QNN Confidence Distribution")
plt.xlabel("Confidence Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# # K-Fold

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import KFold

# --- Ensure correct shape ---
X_seq = np.expand_dims(X_train, axis=-1)  # (samples, 10, 1)
print("Transformer input shape:", X_seq.shape)

# --- K-Fold setup ---
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

train_accs, val_accs, train_losses, val_losses = [], [], [], []

def build_transformer_baseline(input_shape, embed_dim=32, num_heads=4, ff_dim=64, dropout=0.2):
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Dense(embed_dim)(inputs)

    # --- Self-Attention block 1 ---
    attn_out = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(x, x)
    x = tf.keras.layers.Add()([x, attn_out])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)

    ff = tf.keras.Sequential([
        tf.keras.layers.Dense(ff_dim, activation="relu"),
        tf.keras.layers.Dense(embed_dim),
    ])
    ff_out = ff(x)
    x = tf.keras.layers.Add()([x, ff_out])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # --- Self-Attention block 2 (light) ---
    attn_out = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(x, x)
    x = tf.keras.layers.Add()([x, attn_out])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)

    ff_out = ff(x)
    x = tf.keras.layers.Add()([x, ff_out])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # --- Pool + classification head ---
    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = tf.keras.layers.Dense(32, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=0.5),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# --- K-Fold training ---
for fold, (train_idx, val_idx) in enumerate(kf.split(X_seq)):
    print(f"\n🧠 Training Transformer Fold {fold+1}/{k}")

    X_train_fold, X_val_fold = X_seq[train_idx], X_seq[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    model = build_transformer_baseline((X_seq.shape[1], 1))

    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data=(X_val_fold, y_val_fold),
        epochs=20, batch_size=32, verbose=1
    )

    # --- Record last-epoch stats ---
    train_accs.append(history.history['accuracy'])
    val_accs.append(history.history['val_accuracy'])
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])

    val_eval = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    print(f"Fold {fold+1} Validation Accuracy: {val_eval[1]*100:.2f}%")

# --- Summarize ---
print("\n📊 Final K-Fold Results (Transformer Baseline):")
print(f"Train Accuracy: {np.mean(train_accs):.4f} ± {np.std(train_accs):.4f}")
print(f"Val Accuracy:   {np.mean(val_accs):.4f} ± {np.std(val_accs):.4f}")
print(f"Train Loss:     {np.mean(train_losses):.4f} ± {np.std(train_losses):.4f}")
print(f"Val Loss:       {np.mean(val_losses):.4f} ± {np.std(val_losses):.4f}")
# Out:
# Transformer input shape: (2908, 18, 1)
#
# 🧠 Training Transformer Fold 1/5
# Epoch 1/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.5168 - loss: 0.7042 - val_accuracy: 0.4828 - val_loss: 0.6985
# Epoch 2/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5202 - loss: 0.6957 - val_accuracy: 0.4794 - val_loss: 0.7081
# Epoch 3/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5103 - loss: 0.6988 - val_accuracy: 0.4880 - val_loss: 0.7008
# Epoch 4/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5202 - loss: 0.6942 - val_accuracy: 0.4725 - val_loss: 0.6963
# Epoch 5/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5245 - loss: 0.6940 - val_accuracy: 0.4828 - val_loss: 0.6965
# Epoch 6/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5292 - loss: 0.6910 - val_accuracy: 0.5000 - val_loss: 0.6978
# Epoch 7/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5348 - loss: 0.6924 - val_accuracy: 0.4639 - val_loss: 0.6973
# Epoch 8/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5258 - loss: 0.6912 - val_accuracy: 0.4845 - val_loss: 0.6976
# Epoch 9/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5219 - loss: 0.6933 - val_accuracy: 0.4897 - val_loss: 0.6946
# Epoch 10/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5292 - loss: 0.6910 - val_accuracy: 0.4880 - val_loss: 0.6958
# Epoch 11/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5236 - loss: 0.6927 - val_accuracy: 0.4931 - val_loss: 0.6966
# Epoch 12/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5206 - loss: 0.6925 - val_accuracy: 0.5052 - val_loss: 0.6948
# Epoch 13/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.5275 - loss: 0.6921 - val_accuracy: 0.4811 - val_loss: 0.6983
# Epoch 14/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5284 - loss: 0.6912 - val_accuracy: 0.4914 - val_loss: 0.6955
# Epoch 15/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5383 - loss: 0.6905 - val_accuracy: 0.5103 - val_loss: 0.6936
# Epoch 16/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.5374 - loss: 0.6916 - val_accuracy: 0.5172 - val_loss: 0.6938
# Epoch 17/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5404 - loss: 0.6902 - val_accuracy: 0.4897 - val_loss: 0.6952
# Epoch 18/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5434 - loss: 0.6904 - val_accuracy: 0.5052 - val_loss: 0.6949
# Epoch 19/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5344 - loss: 0.6885 - val_accuracy: 0.5103 - val_loss: 0.6933
# Epoch 20/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5314 - loss: 0.6910 - val_accuracy: 0.4966 - val_loss: 0.6953
# Fold 1 Validation Accuracy: 49.66%
#
# 🧠 Training Transformer Fold 2/5
# Epoch 1/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.5090 - loss: 0.7143 - val_accuracy: 0.4708 - val_loss: 0.6976
# Epoch 2/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5125 - loss: 0.7004 - val_accuracy: 0.4931 - val_loss: 0.6972
# Epoch 3/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5138 - loss: 0.6920 - val_accuracy: 0.5206 - val_loss: 0.6960
# Epoch 4/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5155 - loss: 0.6979 - val_accuracy: 0.5172 - val_loss: 0.6958
# Epoch 5/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5224 - loss: 0.6924 - val_accuracy: 0.4931 - val_loss: 0.6963
# Epoch 6/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5249 - loss: 0.6939 - val_accuracy: 0.4966 - val_loss: 0.6974
# Epoch 7/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5129 - loss: 0.6949 - val_accuracy: 0.4674 - val_loss: 0.6958
# Epoch 8/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5421 - loss: 0.6899 - val_accuracy: 0.4948 - val_loss: 0.6945
# Epoch 9/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5387 - loss: 0.6885 - val_accuracy: 0.4897 - val_loss: 0.6985
# Epoch 10/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5387 - loss: 0.6914 - val_accuracy: 0.4983 - val_loss: 0.6968
# Epoch 11/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5396 - loss: 0.6878 - val_accuracy: 0.4863 - val_loss: 0.6975
# Epoch 12/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5236 - loss: 0.6900 - val_accuracy: 0.4948 - val_loss: 0.6954
# Epoch 13/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5288 - loss: 0.6896 - val_accuracy: 0.5258 - val_loss: 0.6942
# Epoch 14/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5434 - loss: 0.6901 - val_accuracy: 0.4966 - val_loss: 0.6971
# Epoch 15/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5340 - loss: 0.6920 - val_accuracy: 0.4948 - val_loss: 0.6955
# Epoch 16/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5404 - loss: 0.6880 - val_accuracy: 0.4794 - val_loss: 0.6987
# Epoch 17/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5224 - loss: 0.6926 - val_accuracy: 0.4948 - val_loss: 0.6956
# Epoch 18/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5400 - loss: 0.6894 - val_accuracy: 0.5052 - val_loss: 0.6953
# Epoch 19/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5353 - loss: 0.6894 - val_accuracy: 0.4948 - val_loss: 0.6958
# Epoch 20/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5331 - loss: 0.6890 - val_accuracy: 0.5120 - val_loss: 0.6939
# Fold 2 Validation Accuracy: 51.20%
#
# 🧠 Training Transformer Fold 3/5
# Epoch 1/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.4953 - loss: 0.7210 - val_accuracy: 0.5481 - val_loss: 0.6882
# Epoch 2/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5107 - loss: 0.6954 - val_accuracy: 0.5481 - val_loss: 0.6897
# Epoch 3/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5056 - loss: 0.6947 - val_accuracy: 0.5550 - val_loss: 0.6881
# Epoch 4/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5064 - loss: 0.6954 - val_accuracy: 0.5619 - val_loss: 0.6875
# Epoch 5/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5056 - loss: 0.6959 - val_accuracy: 0.5533 - val_loss: 0.6870
# Epoch 6/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4953 - loss: 0.6955 - val_accuracy: 0.5687 - val_loss: 0.6888
# Epoch 7/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4910 - loss: 0.6941 - val_accuracy: 0.5309 - val_loss: 0.6914
# Epoch 8/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5236 - loss: 0.6925 - val_accuracy: 0.5704 - val_loss: 0.6900
# Epoch 9/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5129 - loss: 0.6916 - val_accuracy: 0.5670 - val_loss: 0.6865
# Epoch 10/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5103 - loss: 0.6939 - val_accuracy: 0.5447 - val_loss: 0.6910
# Epoch 11/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5172 - loss: 0.6919 - val_accuracy: 0.5636 - val_loss: 0.6887
# Epoch 12/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5206 - loss: 0.6923 - val_accuracy: 0.5498 - val_loss: 0.6895
# Epoch 13/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5236 - loss: 0.6923 - val_accuracy: 0.5361 - val_loss: 0.6921
# Epoch 14/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5150 - loss: 0.6939 - val_accuracy: 0.5292 - val_loss: 0.6906
# Epoch 15/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5206 - loss: 0.6908 - val_accuracy: 0.5550 - val_loss: 0.6886
# Epoch 16/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5271 - loss: 0.6906 - val_accuracy: 0.5550 - val_loss: 0.6892
# Epoch 17/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5275 - loss: 0.6892 - val_accuracy: 0.5670 - val_loss: 0.6877
# Epoch 18/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5163 - loss: 0.6910 - val_accuracy: 0.5619 - val_loss: 0.6848
# Epoch 19/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5159 - loss: 0.6915 - val_accuracy: 0.5550 - val_loss: 0.6862
# Epoch 20/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5327 - loss: 0.6887 - val_accuracy: 0.5739 - val_loss: 0.6868
# Fold 3 Validation Accuracy: 57.39%
#
# 🧠 Training Transformer Fold 4/5
# Epoch 1/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - accuracy: 0.4981 - loss: 0.7129 - val_accuracy: 0.4957 - val_loss: 0.6965
# Epoch 2/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5140 - loss: 0.6982 - val_accuracy: 0.4940 - val_loss: 0.6983
# Epoch 3/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4886 - loss: 0.6976 - val_accuracy: 0.5146 - val_loss: 0.6918
# Epoch 4/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5088 - loss: 0.6960 - val_accuracy: 0.4991 - val_loss: 0.6942
# Epoch 5/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5024 - loss: 0.6969 - val_accuracy: 0.5095 - val_loss: 0.6931
# Epoch 6/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4938 - loss: 0.6942 - val_accuracy: 0.5198 - val_loss: 0.6925
# Epoch 7/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5221 - loss: 0.6934 - val_accuracy: 0.5267 - val_loss: 0.6925
# Epoch 8/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5092 - loss: 0.6935 - val_accuracy: 0.5215 - val_loss: 0.6908
# Epoch 9/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5187 - loss: 0.6929 - val_accuracy: 0.5129 - val_loss: 0.6924
# Epoch 10/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5165 - loss: 0.6938 - val_accuracy: 0.5611 - val_loss: 0.6893
# Epoch 11/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5058 - loss: 0.6961 - val_accuracy: 0.5663 - val_loss: 0.6903
# Epoch 12/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5110 - loss: 0.6918 - val_accuracy: 0.5267 - val_loss: 0.6901
# Epoch 13/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5067 - loss: 0.6925 - val_accuracy: 0.5473 - val_loss: 0.6904
# Epoch 14/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5217 - loss: 0.6927 - val_accuracy: 0.5232 - val_loss: 0.6902
# Epoch 15/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5208 - loss: 0.6929 - val_accuracy: 0.5439 - val_loss: 0.6890
# Epoch 16/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5196 - loss: 0.6927 - val_accuracy: 0.5422 - val_loss: 0.6896
# Epoch 17/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5226 - loss: 0.6922 - val_accuracy: 0.5422 - val_loss: 0.6900
# Epoch 18/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5230 - loss: 0.6933 - val_accuracy: 0.5594 - val_loss: 0.6893
# Epoch 19/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5256 - loss: 0.6912 - val_accuracy: 0.5611 - val_loss: 0.6893
# Epoch 20/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5187 - loss: 0.6913 - val_accuracy: 0.5456 - val_loss: 0.6884
# Fold 4 Validation Accuracy: 54.56%
#
# 🧠 Training Transformer Fold 5/5
# Epoch 1/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.5088 - loss: 0.7060 - val_accuracy: 0.4733 - val_loss: 0.7019
# Epoch 2/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5071 - loss: 0.6979 - val_accuracy: 0.4836 - val_loss: 0.6977
# Epoch 3/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4976 - loss: 0.6980 - val_accuracy: 0.4544 - val_loss: 0.6955
# Epoch 4/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5049 - loss: 0.6926 - val_accuracy: 0.5404 - val_loss: 0.6923
# Epoch 5/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5153 - loss: 0.6968 - val_accuracy: 0.5473 - val_loss: 0.6904
# Epoch 6/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5118 - loss: 0.6934 - val_accuracy: 0.4871 - val_loss: 0.6939
# Epoch 7/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5058 - loss: 0.6947 - val_accuracy: 0.5284 - val_loss: 0.6935
# Epoch 8/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5230 - loss: 0.6933 - val_accuracy: 0.5181 - val_loss: 0.6927
# Epoch 9/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5088 - loss: 0.6917 - val_accuracy: 0.5026 - val_loss: 0.6921
# Epoch 10/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5088 - loss: 0.6938 - val_accuracy: 0.5456 - val_loss: 0.6908
# Epoch 11/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5127 - loss: 0.6929 - val_accuracy: 0.5663 - val_loss: 0.6905
# Epoch 12/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5170 - loss: 0.6912 - val_accuracy: 0.5129 - val_loss: 0.6923
# Epoch 13/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5127 - loss: 0.6940 - val_accuracy: 0.5318 - val_loss: 0.6900
# Epoch 14/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5251 - loss: 0.6925 - val_accuracy: 0.5250 - val_loss: 0.6904
# Epoch 15/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5196 - loss: 0.6920 - val_accuracy: 0.5284 - val_loss: 0.6905
# Epoch 16/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5247 - loss: 0.6919 - val_accuracy: 0.5404 - val_loss: 0.6907
# Epoch 17/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5290 - loss: 0.6910 - val_accuracy: 0.5301 - val_loss: 0.6912
# Epoch 18/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5114 - loss: 0.6909 - val_accuracy: 0.5250 - val_loss: 0.6895
# Epoch 19/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5428 - loss: 0.6902 - val_accuracy: 0.5198 - val_loss: 0.6914
# Epoch 20/20
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5118 - loss: 0.6933 - val_accuracy: 0.5301 - val_loss: 0.6918
# Fold 5 Validation Accuracy: 53.01%
#
# 📊 Final K-Fold Results (Transformer Baseline):
# Train Accuracy: 0.5195 ± 0.0125
# Val Accuracy:   0.5186 ± 0.0297
# Train Loss:     0.6937 ± 0.0050
# Val Loss:       0.6931 ± 0.0039

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Convert lists to arrays ---
train_accs = np.array(train_accs)
val_accs = np.array(val_accs)
train_losses = np.array(train_losses)
val_losses = np.array(val_losses)

# --- Compute mean across folds (per epoch) ---
mean_train_acc = np.mean(train_accs, axis=0)
mean_val_acc = np.mean(val_accs, axis=0)
mean_train_loss = np.mean(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)

# --- Final mean accuracy (last epoch) ---
final_accuracy = np.mean(val_accs)
print(f"\nFinal Transformer K-Fold Validation Accuracy: {final_accuracy:.4f}")

# --- Plotting ---
plt.figure(figsize=(10, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(mean_train_acc, label='Train Accuracy')
plt.plot(mean_val_acc, label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Parkinson’s Transformer Baseline - Mean Accuracy Over Folds")
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(mean_train_loss, label='Train Loss')
plt.plot(mean_val_loss, label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Parkinson’s Transformer Baseline - Mean Loss Over Folds")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final Transformer K-Fold Validation Accuracy: 0.5186

# %%
import pandas as pd
import numpy as np

# Convert lists to numpy arrays
folds = list(range(1, len(train_accs) + 1))

# Create DataFrame with results per fold
df_results = pd.DataFrame({
    'Fold': folds,
    'Final Train Accuracy': [train_acc[-1] for train_acc in train_accs],
    'Final Validation Accuracy': [val_acc[-1] for val_acc in val_accs],
    'Final Train Loss': [train_loss[-1] for train_loss in train_losses],
    'Final Validation Loss': [val_loss[-1] for val_loss in val_losses]
})

# Print results
print("\n📊 K-Fold Cross-Validation Results:\n")
print(df_results)

# Compute summary statistics (mean & std deviation)
df_summary = df_results.describe().loc[['mean', 'std']]
print("\n📌 Summary Statistics (Mean & Std Deviation):\n")
print(df_summary)
# Out:
# 📊 K-Fold Cross-Validation Results:
#
#    Fold  Final Train Accuracy  Final Validation Accuracy  Final Train Loss  \
# 0     1              0.531384                   0.496564          0.690981
# 1     2              0.533104                   0.512028          0.688988
# 2     3              0.532674                   0.573883          0.688704
# 3     4              0.518694                   0.545611          0.691272
# 4     5              0.511818                   0.530120          0.693312
#
#    Final Validation Loss
# 0               0.695320
# 1               0.693917
# 2               0.686757
# 3               0.688376
# 4               0.691783
#
# 📌 Summary Statistics (Mean & Std Deviation):
#
#           Fold  Final Train Accuracy  Final Validation Accuracy  \
# mean  3.000000              0.525535                   0.531641
# std   1.581139              0.009714                   0.029987
#
#       Final Train Loss  Final Validation Loss
# mean          0.690652                0.69123
# std           0.001880                0.00362

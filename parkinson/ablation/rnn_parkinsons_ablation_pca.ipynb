# %%
import pandas as pd

# Load full quantum features
df = pd.read_csv("final_parkinsons_features.csv")

print(f"✅ Loaded full quantum features: {df.shape[1]} columns.")
# Out:
# ✅ Loaded full quantum features: 22 columns.

# %%
df.head()
# Out:
#    Unnamed: 0  Gait_Cycle_Percent  \
# 0           0                   1
# 1           1                   2
# 2           2                   3
# 3           3                   4
# 4           4                   5
#
#    Left_Ankle_Ankle_Dorsi_Plantarflexion_PF_DF  \
# 0                                     -2.37648
# 1                                     -1.87879
# 2                                     -1.15549
# 3                                     -0.21892
# 4                                      0.88757
#
#    Left_Hip_Hip_Flexion_Extension_EXT_FLX  \
# 0                                34.02794
# 1                                33.60433
# 2                                33.26338
# 3                                33.00112
# 4                                32.78223
#
#    Left_Knee_Knee_Flx_Extension_EXT_FLX  \
# 0                              16.14490
# 1                              16.86324
# 2                              17.86806
# 3                              19.09299
# 4                              20.42713
#
#    Right_Ankle_Ankle_Dorsi_Plantarflexion_PF_DF  \
# 0                                       1.87055
# 1                                       0.98626
# 2                                       0.16397
# 3                                      -0.47002
# 4                                      -0.80742
#
#    Right_Hip_Hip_Flexion_Extension_EXT_FLX  \
# 0                                 33.60558
# 1                                 33.50635
# 2                                 33.50398
# 3                                 33.58014
# 4                                 33.70621
#
#    Right_Knee_Knee_Flx_Extension_EXT_FLX Subject_ID  label  ...  \
# 0                               11.36783    SUB01_1      1  ...
# 1                               11.34289    SUB01_1      1  ...
# 2                               11.92080    SUB01_1      1  ...
# 3                               13.01924    SUB01_1      1  ...
# 4                               14.51952    SUB01_1      1  ...
#
#    Left_Knee_Ang_Knee_Flx_Extension_Variability  \
# 0                                     18.945746
# 1                                     18.945746
# 2                                     18.945746
# 3                                     18.945746
# 4                                     18.945746
#
#    Right_Ankle_Ang_Ankle_Dorsi_Plantarflexion_Variability  \
# 0                                           7.692659
# 1                                           7.692659
# 2                                           7.692659
# 3                                           7.692659
# 4                                           7.692659
#
#    Right_Hip_Ang_Hip_Flexion_Extension_Variability  \
# 0                                        15.308019
# 1                                        15.308019
# 2                                        15.308019
# 3                                        15.308019
# 4                                        15.308019
#
#    Right_Knee_Ang_Knee_Flx_Extension_Variability  \
# 0                                      18.810668
# 1                                      18.810668
# 2                                      18.810668
# 3                                      18.810668
# 4                                      18.810668
#
#    Left_Ankle_Ang_Ankle_Dorsi_Plantarflexion_Acceleration  \
# 0                                            0.00000
# 1                                            0.49769
# 2                                            0.72330
# 3                                            0.93657
# 4                                            1.10649
#
#    Left_Hip_Ang_Hip_Flexion_Extension_Acceleration  \
# 0                                          0.00000
# 1                                         -0.42361
# 2                                         -0.34095
# 3                                         -0.26226
# 4                                         -0.21889
#
#    Left_Knee_Ang_Knee_Flx_Extension_Acceleration  \
# 0                                        0.00000
# 1                                        0.71834
# 2                                        1.00482
# 3                                        1.22493
# 4                                        1.33414
#
#    Right_Ankle_Ang_Ankle_Dorsi_Plantarflexion_Acceleration  \
# 0                                            0.00000
# 1                                           -0.88429
# 2                                           -0.82229
# 3                                           -0.63399
# 4                                           -0.33740
#
#    Right_Hip_Ang_Hip_Flexion_Extension_Acceleration  \
# 0                                           0.00000
# 1                                          -0.09923
# 2                                          -0.00237
# 3                                           0.07616
# 4                                           0.12607
#
#    Right_Knee_Ang_Knee_Flx_Extension_Acceleration
# 0                                         0.00000
# 1                                        -0.02494
# 2                                         0.57791
# 3                                         1.09844
# 4                                         1.50028
#
# [5 rows x 22 columns]

# %%
import matplotlib.pyplot as plt

def plot_history(history, title):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    # Accuracy Plot
    axs[0].plot(history.history['accuracy'], label="Train Accuracy")
    axs[0].plot(history.history['val_accuracy'], label="Validation Accuracy")
    axs[0].set_title(f"Model Accuracy - {title}")
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend()

    # Loss Plot
    axs[1].plot(history.history['loss'], label="Train Loss")
    axs[1].plot(history.history['val_loss'], label="Validation Loss")
    axs[1].set_title(f"Model Loss - {title}")
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")
    axs[1].legend()

    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = df.drop(columns=["Subject_ID","Gait_Cycle_Percent","Unnamed: 0"])
df_corr = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature-Label Correlation")
plt.show()

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.layers import BatchNormalization, Dropout

tf.keras.backend.set_floatx('float32')

# Ensure features and labels are correctly extracted
X = df.drop(columns=["label"]).values  # Features
y = df["label"].values  # Labels

# Convert labels to one-hot encoding *before* splitting
y_onehot = tf.keras.utils.to_categorical(y, num_classes=2)

# Split once: train + temp
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y_onehot, random_state=42)

# Split again: train + val (from temp)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42)

# ✅ Remove MinMaxScaler, keep StandardScaler
scaler = StandardScaler()  # StandardScaler ensures proper feature scaling for PCA
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# Convert to float32 (required for TensorFlow)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
y_train = y_train.astype("float32")
X_val = X_val.astype("float32")

print(f"✅ X_train Labels shape: {y_train.shape}, {y_train.shape}")
print(f"✅ X_val Labels shape: {y_val.shape}, {y_val.shape}")
print(f"✅ X_test Labels shape: {y_test.shape}, {y_test.shape}")
# Out:
# ✅ X_train Labels shape: (2908,), (2908,)
# ✅ X_val Labels shape: (970,), (970,)
# ✅ X_test Labels shape: (970,), (970,)

# %%
# Sequential model (LSTM)
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], 1)),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss="binary_crossentropy",
              metrics=["accuracy"])

if len(y_train.shape) > 1 and y_train.shape[1] > 1:
    y_train = np.argmax(y_train, axis=1)
    y_test = np.argmax(y_test, axis=1)

# Train
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val), batch_size=32, verbose=1)
# Out:
# Epoch 1/20
# 91/91 [==============================] - 4s 17ms/step - loss: 0.6934 - accuracy: 0.4983 - val_loss: 0.6925 - val_accuracy: 0.5206
# Epoch 2/20
# 91/91 [==============================] - 1s 10ms/step - loss: 0.6927 - accuracy: 0.5196 - val_loss: 0.6921 - val_accuracy: 0.5216
# Epoch 3/20
# 91/91 [==============================] - 1s 10ms/step - loss: 0.6922 - accuracy: 0.5210 - val_loss: 0.6918 - val_accuracy: 0.5216
# Epoch 4/20
# 91/91 [==============================] - 1s 10ms/step - loss: 0.6920 - accuracy: 0.5213 - val_loss: 0.6916 - val_accuracy: 0.5216
# Epoch 5/20
# 91/91 [==============================] - 1s 11ms/step - loss: 0.6918 - accuracy: 0.5189 - val_loss: 0.6914 - val_accuracy: 0.5216
# Epoch 6/20
# 91/91 [==============================] - 1s 11ms/step - loss: 0.6915 - accuracy: 0.5213 - val_loss: 0.6912 - val_accuracy: 0.5206
# Epoch 7/20
# 91/91 [==============================] - 1s 11ms/step - loss: 0.6914 - accuracy: 0.5203 - val_loss: 0.6912 - val_accuracy: 0.5165
# Epoch 8/20
# 91/91 [==============================] - 1s 11ms/step - loss: 0.6912 - accuracy: 0.5210 - val_loss: 0.6912 - val_accuracy: 0.5186
# Epoch 9/20
# 91/91 [==============================] - 1s 11ms/step - loss: 0.6911 - accuracy: 0.5193 - val_loss: 0.6912 - val_accuracy: 0.5165
# Epoch 10/20
# 91/91 [==============================] - 1s 10ms/step - loss: 0.6910 - accuracy: 0.5141 - val_loss: 0.6912 - val_accuracy: 0.5165
# Epoch 11/20
# 91/91 [==============================] - 1s 10ms/step - loss: 0.6909 - accuracy: 0.5227 - val_loss: 0.6911 - val_accuracy: 0.5206
# Epoch 12/20
# 91/91 [==============================] - 1s 11ms/step - loss: 0.6908 - accuracy: 0.5213 - val_loss: 0.6911 - val_accuracy: 0.5247
# Epoch 13/20
# 91/91 [==============================] - 1s 13ms/step - loss: 0.6906 - accuracy: 0.5206 - val_loss: 0.6911 - val_accuracy: 0.5237
# Epoch 14/20
# 91/91 [==============================] - 1s 12ms/step - loss: 0.6906 - accuracy: 0.5234 - val_loss: 0.6913 - val_accuracy: 0.5206
# Epoch 15/20
# 91/91 [==============================] - 1s 11ms/step - loss: 0.6904 - accuracy: 0.5285 - val_loss: 0.6912 - val_accuracy: 0.5258
# Epoch 16/20
# 91/91 [==============================] - 1s 11ms/step - loss: 0.6903 - accuracy: 0.5237 - val_loss: 0.6912 - val_accuracy: 0.5309
# Epoch 17/20
# 91/91 [==============================] - 1s 14ms/step - loss: 0.6903 - accuracy: 0.5316 - val_loss: 0.6911 - val_accuracy: 0.5309
# Epoch 18/20
# 91/91 [==============================] - 1s 12ms/step - loss: 0.6900 - accuracy: 0.5296 - val_loss: 0.6912 - val_accuracy: 0.5289
# Epoch 19/20
# 91/91 [==============================] - 1s 14ms/step - loss: 0.6900 - accuracy: 0.5351 - val_loss: 0.6914 - val_accuracy: 0.5206
# Epoch 20/20
# 91/91 [==============================] - 1s 15ms/step - loss: 0.6899 - accuracy: 0.5347 - val_loss: 0.6914 - val_accuracy: 0.5237

# %%
plot_history(history, "QNN Quantum+PCA Reduced Features")

# %%
# ✅ Evaluate
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"QNN Test Accuracy: {test_acc:.4f} | Loss: {test_loss:.4f}")
# Out:
# 31/31 [==============================] - 0s 7ms/step - loss: 0.6920 - accuracy: 0.5299
# QNN Test Accuracy: 0.5299 | Loss: 0.6920

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 🔹 Step 1: Get prediction probabilities
y_pred_probs = model.predict(X_test)

# 🔹 Step 2: Binarize predictions (assuming sigmoid output layer)
y_pred = (y_pred_probs > 0.5).astype(int).flatten()

# 🔹 Step 3: Decode true labels if they're one-hot encoded
if len(y_test.shape) > 1 and y_test.shape[1] > 1:
    y_test = np.argmax(y_test, axis=1)  # convert [0,1] to 1 and [1,0] to 0

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt=".0f", cmap="Blues",
            xticklabels=["Off", "On"], yticklabels=["Off", "On"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - QE-RNN Model")
plt.show()

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# 31/31 [==============================] - 1s 6ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.09      0.16       465
#            1       0.53      0.93      0.67       505
#
#     accuracy                           0.53       970
#    macro avg       0.54      0.51      0.42       970
# weighted avg       0.54      0.53      0.43       970

# %% [markdown]
# # Confidence Check

# %%
import numpy as np

# Get model predictions
y_pred_probs = model.predict(X_test)

# Check confidence distribution
print("Min Confidence:", np.min(y_pred_probs))
print("Max Confidence:", np.max(y_pred_probs))
print("Mean Confidence:", np.mean(y_pred_probs))
# Out:
# 31/31 [==============================] - 0s 5ms/step
# Min Confidence: 0.2983343
# Max Confidence: 0.7784261
# Mean Confidence: 0.5288222

# %%
y_true_qnn = y_test# Convert one-hot labels to class labels
y_pred_qnn = np.argmax(model.predict(X_test), axis=1)
confidences_qnn = np.max(model.predict(X_test), axis=1)

# Convert to numpy arrays if needed
qnn_confidences = np.array(confidences_qnn)  # Replace with your QNN confidence list

plt.figure(figsize=(10, 5))

# QNN Confidence Distribution
plt.subplot(1, 2, 1)
plt.hist(qnn_confidences, bins=20, color='blue', alpha=0.7, edgecolor='black')
plt.title("QNN Confidence Distribution")
plt.xlabel("Confidence Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
# Out:
# 31/31 [==============================] - 0s 5ms/step
# 31/31 [==============================] - 0s 5ms/step

# %% [markdown]
# # K-Fold

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# Define number of folds
k = 5  
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Store metrics
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []

# Placeholder for epoch-wise averaging
all_train_acc = []
all_val_acc = []
all_train_loss = []
all_val_loss = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
    print(f"\nTraining Fold {fold+1}/{k}")

    # Split data
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # Define LSTM model
    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], 1)),
        tf.keras.layers.LSTM(32),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, clipvalue=0.5),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])

    # Train model
    history = model.fit(X_train_fold, y_train_fold, 
                        epochs=20, batch_size=32, 
                        validation_data=(X_val_fold, y_val_fold), 
                        verbose=1)

    # Store per-epoch results
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])

    # Evaluate model
    _, accuracy = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    print(f"Fold {fold+1} Accuracy: {accuracy:.4f}")
# Out:
# Training Fold 1/5
# Epoch 1/20
# 73/73 [==============================] - 4s 17ms/step - loss: 0.6930 - accuracy: 0.5232 - val_loss: 0.6933 - val_accuracy: 0.4897
# Epoch 2/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6924 - accuracy: 0.5271 - val_loss: 0.6933 - val_accuracy: 0.4931
# Epoch 3/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6920 - accuracy: 0.5284 - val_loss: 0.6932 - val_accuracy: 0.4931
# Epoch 4/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6918 - accuracy: 0.5284 - val_loss: 0.6938 - val_accuracy: 0.4931
# Epoch 5/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6915 - accuracy: 0.5284 - val_loss: 0.6938 - val_accuracy: 0.4931
# Epoch 6/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6913 - accuracy: 0.5284 - val_loss: 0.6942 - val_accuracy: 0.4931
# Epoch 7/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6911 - accuracy: 0.5288 - val_loss: 0.6940 - val_accuracy: 0.4931
# Epoch 8/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6909 - accuracy: 0.5288 - val_loss: 0.6943 - val_accuracy: 0.4931
# Epoch 9/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6908 - accuracy: 0.5297 - val_loss: 0.6947 - val_accuracy: 0.4931
# Epoch 10/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6905 - accuracy: 0.5297 - val_loss: 0.6940 - val_accuracy: 0.4931
# Epoch 11/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6905 - accuracy: 0.5297 - val_loss: 0.6945 - val_accuracy: 0.4931
# Epoch 12/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6902 - accuracy: 0.5297 - val_loss: 0.6943 - val_accuracy: 0.4931
# Epoch 13/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6901 - accuracy: 0.5297 - val_loss: 0.6944 - val_accuracy: 0.4931
# Epoch 14/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6900 - accuracy: 0.5297 - val_loss: 0.6945 - val_accuracy: 0.4931
# Epoch 15/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6898 - accuracy: 0.5310 - val_loss: 0.6943 - val_accuracy: 0.4914
# Epoch 16/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6898 - accuracy: 0.5292 - val_loss: 0.6939 - val_accuracy: 0.4845
# Epoch 17/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6895 - accuracy: 0.5305 - val_loss: 0.6941 - val_accuracy: 0.4863
# Epoch 18/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6893 - accuracy: 0.5314 - val_loss: 0.6942 - val_accuracy: 0.4880
# Epoch 19/20
# 73/73 [==============================] - 1s 13ms/step - loss: 0.6892 - accuracy: 0.5305 - val_loss: 0.6941 - val_accuracy: 0.4880
# Epoch 20/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6890 - accuracy: 0.5297 - val_loss: 0.6939 - val_accuracy: 0.4863
# Fold 1 Accuracy: 0.4863
#
# Training Fold 2/5
# Epoch 1/20
# 73/73 [==============================] - 3s 19ms/step - loss: 0.6929 - accuracy: 0.5077 - val_loss: 0.6937 - val_accuracy: 0.4983
# Epoch 2/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6921 - accuracy: 0.5267 - val_loss: 0.6944 - val_accuracy: 0.4983
# Epoch 3/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6916 - accuracy: 0.5275 - val_loss: 0.6956 - val_accuracy: 0.4966
# Epoch 4/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6910 - accuracy: 0.5279 - val_loss: 0.6964 - val_accuracy: 0.4966
# Epoch 5/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6907 - accuracy: 0.5292 - val_loss: 0.6965 - val_accuracy: 0.4948
# Epoch 6/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6905 - accuracy: 0.5288 - val_loss: 0.6968 - val_accuracy: 0.4966
# Epoch 7/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6903 - accuracy: 0.5284 - val_loss: 0.6975 - val_accuracy: 0.4948
# Epoch 8/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6902 - accuracy: 0.5275 - val_loss: 0.6971 - val_accuracy: 0.4948
# Epoch 9/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6899 - accuracy: 0.5292 - val_loss: 0.6973 - val_accuracy: 0.4931
# Epoch 10/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6902 - accuracy: 0.5275 - val_loss: 0.6968 - val_accuracy: 0.4931
# Epoch 11/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6898 - accuracy: 0.5297 - val_loss: 0.6971 - val_accuracy: 0.4931
# Epoch 12/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6897 - accuracy: 0.5297 - val_loss: 0.6970 - val_accuracy: 0.4948
# Epoch 13/20
# 73/73 [==============================] - 1s 12ms/step - loss: 0.6896 - accuracy: 0.5301 - val_loss: 0.6968 - val_accuracy: 0.4948
# Epoch 14/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6896 - accuracy: 0.5262 - val_loss: 0.6968 - val_accuracy: 0.4948
# Epoch 15/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6894 - accuracy: 0.5284 - val_loss: 0.6964 - val_accuracy: 0.4966
# Epoch 16/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6892 - accuracy: 0.5271 - val_loss: 0.6972 - val_accuracy: 0.4983
# Epoch 17/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6891 - accuracy: 0.5241 - val_loss: 0.6973 - val_accuracy: 0.5000
# Epoch 18/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6890 - accuracy: 0.5267 - val_loss: 0.6971 - val_accuracy: 0.5000
# Epoch 19/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6890 - accuracy: 0.5297 - val_loss: 0.6968 - val_accuracy: 0.4966
# Epoch 20/20
# 73/73 [==============================] - 1s 12ms/step - loss: 0.6888 - accuracy: 0.5284 - val_loss: 0.6965 - val_accuracy: 0.4948
# Fold 2 Accuracy: 0.4948
#
# Training Fold 3/5
# Epoch 1/20
# 73/73 [==============================] - 4s 19ms/step - loss: 0.6931 - accuracy: 0.5009 - val_loss: 0.6924 - val_accuracy: 0.5567
# Epoch 2/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6928 - accuracy: 0.5064 - val_loss: 0.6921 - val_accuracy: 0.5653
# Epoch 3/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6926 - accuracy: 0.5116 - val_loss: 0.6915 - val_accuracy: 0.5601
# Epoch 4/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6924 - accuracy: 0.5133 - val_loss: 0.6915 - val_accuracy: 0.5619
# Epoch 5/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6923 - accuracy: 0.5206 - val_loss: 0.6915 - val_accuracy: 0.5412
# Epoch 6/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6921 - accuracy: 0.5219 - val_loss: 0.6912 - val_accuracy: 0.5395
# Epoch 7/20
# 73/73 [==============================] - 1s 12ms/step - loss: 0.6919 - accuracy: 0.5215 - val_loss: 0.6911 - val_accuracy: 0.5412
# Epoch 8/20
# 73/73 [==============================] - 1s 12ms/step - loss: 0.6917 - accuracy: 0.5241 - val_loss: 0.6906 - val_accuracy: 0.5498
# Epoch 9/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6915 - accuracy: 0.5310 - val_loss: 0.6905 - val_accuracy: 0.5464
# Epoch 10/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6913 - accuracy: 0.5185 - val_loss: 0.6906 - val_accuracy: 0.5430
# Epoch 11/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6911 - accuracy: 0.5189 - val_loss: 0.6902 - val_accuracy: 0.5481
# Epoch 12/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.6909 - accuracy: 0.5245 - val_loss: 0.6903 - val_accuracy: 0.5395
# Epoch 13/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6907 - accuracy: 0.5232 - val_loss: 0.6900 - val_accuracy: 0.5464
# Epoch 14/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6905 - accuracy: 0.5292 - val_loss: 0.6901 - val_accuracy: 0.5361
# Epoch 15/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6903 - accuracy: 0.5228 - val_loss: 0.6899 - val_accuracy: 0.5344
# Epoch 16/20
# 73/73 [==============================] - 1s 11ms/step - loss: 0.6901 - accuracy: 0.5267 - val_loss: 0.6898 - val_accuracy: 0.5292
# Epoch 17/20
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6901 - accuracy: 0.5215 - val_loss: 0.6896 - val_accuracy: 0.5309
# Epoch 18/20
# 73/73 [==============================] - 1s 19ms/step - loss: 0.6900 - accuracy: 0.5275 - val_loss: 0.6896 - val_accuracy: 0.5275
# Epoch 19/20
# 73/73 [==============================] - 1s 18ms/step - loss: 0.6896 - accuracy: 0.5271 - val_loss: 0.6895 - val_accuracy: 0.5344
# Epoch 20/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6894 - accuracy: 0.5279 - val_loss: 0.6893 - val_accuracy: 0.5412
# Fold 3 Accuracy: 0.5412
#
# Training Fold 4/5
# Epoch 1/20
# 73/73 [==============================] - 5s 23ms/step - loss: 0.6937 - accuracy: 0.4908 - val_loss: 0.6942 - val_accuracy: 0.5060
# Epoch 2/20
# 73/73 [==============================] - 1s 12ms/step - loss: 0.6928 - accuracy: 0.5105 - val_loss: 0.6936 - val_accuracy: 0.4940
# Epoch 3/20
# 73/73 [==============================] - 1s 12ms/step - loss: 0.6924 - accuracy: 0.5105 - val_loss: 0.6934 - val_accuracy: 0.4940
# Epoch 4/20
# 73/73 [==============================] - 1s 12ms/step - loss: 0.6920 - accuracy: 0.5092 - val_loss: 0.6931 - val_accuracy: 0.5043
# Epoch 5/20
# 73/73 [==============================] - 1s 10ms/step - loss: 0.6918 - accuracy: 0.5144 - val_loss: 0.6931 - val_accuracy: 0.5112
# Epoch 6/20
# 73/73 [==============================] - 2s 22ms/step - loss: 0.6916 - accuracy: 0.5208 - val_loss: 0.6930 - val_accuracy: 0.5112
# Epoch 7/20
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6914 - accuracy: 0.5256 - val_loss: 0.6928 - val_accuracy: 0.5077
# Epoch 8/20
# 73/73 [==============================] - 1s 15ms/step - loss: 0.6913 - accuracy: 0.5269 - val_loss: 0.6928 - val_accuracy: 0.5077
# Epoch 9/20
# 73/73 [==============================] - 1s 19ms/step - loss: 0.6911 - accuracy: 0.5264 - val_loss: 0.6927 - val_accuracy: 0.5095
# Epoch 10/20
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6908 - accuracy: 0.5256 - val_loss: 0.6925 - val_accuracy: 0.5112
# Epoch 11/20
# 73/73 [==============================] - 1s 18ms/step - loss: 0.6906 - accuracy: 0.5260 - val_loss: 0.6925 - val_accuracy: 0.5146
# Epoch 12/20
# 73/73 [==============================] - 1s 20ms/step - loss: 0.6903 - accuracy: 0.5260 - val_loss: 0.6924 - val_accuracy: 0.5146
# Epoch 13/20
# 73/73 [==============================] - 1s 15ms/step - loss: 0.6900 - accuracy: 0.5251 - val_loss: 0.6929 - val_accuracy: 0.5146
# Epoch 14/20
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6899 - accuracy: 0.5256 - val_loss: 0.6926 - val_accuracy: 0.5077
# Epoch 15/20
# 73/73 [==============================] - 1s 15ms/step - loss: 0.6897 - accuracy: 0.5243 - val_loss: 0.6927 - val_accuracy: 0.5146
# Epoch 16/20
# 73/73 [==============================] - 1s 19ms/step - loss: 0.6894 - accuracy: 0.5256 - val_loss: 0.6928 - val_accuracy: 0.5181
# Epoch 17/20
# 73/73 [==============================] - 2s 32ms/step - loss: 0.6892 - accuracy: 0.5251 - val_loss: 0.6929 - val_accuracy: 0.5164
# Epoch 18/20
# 73/73 [==============================] - 2s 31ms/step - loss: 0.6890 - accuracy: 0.5294 - val_loss: 0.6930 - val_accuracy: 0.5267
# Epoch 19/20
# 73/73 [==============================] - 2s 30ms/step - loss: 0.6888 - accuracy: 0.5260 - val_loss: 0.6930 - val_accuracy: 0.5318
# Epoch 20/20
# 73/73 [==============================] - 2s 31ms/step - loss: 0.6885 - accuracy: 0.5324 - val_loss: 0.6929 - val_accuracy: 0.5491
# Fold 4 Accuracy: 0.5491
#
# Training Fold 5/5
# Epoch 1/20
# 73/73 [==============================] - 4s 22ms/step - loss: 0.6935 - accuracy: 0.4886 - val_loss: 0.6930 - val_accuracy: 0.5198
# Epoch 2/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6927 - accuracy: 0.5131 - val_loss: 0.6924 - val_accuracy: 0.5353
# Epoch 3/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6924 - accuracy: 0.5157 - val_loss: 0.6920 - val_accuracy: 0.5336
# Epoch 4/20
# 73/73 [==============================] - 1s 15ms/step - loss: 0.6920 - accuracy: 0.5135 - val_loss: 0.6919 - val_accuracy: 0.5318
# Epoch 5/20
# 73/73 [==============================] - 1s 15ms/step - loss: 0.6919 - accuracy: 0.5165 - val_loss: 0.6917 - val_accuracy: 0.5370
# Epoch 6/20
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6916 - accuracy: 0.5135 - val_loss: 0.6915 - val_accuracy: 0.5318
# Epoch 7/20
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6914 - accuracy: 0.5200 - val_loss: 0.6914 - val_accuracy: 0.5370
# Epoch 8/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6913 - accuracy: 0.5191 - val_loss: 0.6914 - val_accuracy: 0.5370
# Epoch 9/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6912 - accuracy: 0.5174 - val_loss: 0.6914 - val_accuracy: 0.5387
# Epoch 10/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6910 - accuracy: 0.5230 - val_loss: 0.6912 - val_accuracy: 0.5353
# Epoch 11/20
# 73/73 [==============================] - 1s 15ms/step - loss: 0.6907 - accuracy: 0.5178 - val_loss: 0.6911 - val_accuracy: 0.5404
# Epoch 12/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6906 - accuracy: 0.5170 - val_loss: 0.6911 - val_accuracy: 0.5404
# Epoch 13/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6905 - accuracy: 0.5200 - val_loss: 0.6911 - val_accuracy: 0.5387
# Epoch 14/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6903 - accuracy: 0.5264 - val_loss: 0.6910 - val_accuracy: 0.5422
# Epoch 15/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6902 - accuracy: 0.5320 - val_loss: 0.6909 - val_accuracy: 0.5336
# Epoch 16/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6900 - accuracy: 0.5299 - val_loss: 0.6908 - val_accuracy: 0.5370
# Epoch 17/20
# 73/73 [==============================] - 1s 15ms/step - loss: 0.6898 - accuracy: 0.5337 - val_loss: 0.6907 - val_accuracy: 0.5250
# Epoch 18/20
# 73/73 [==============================] - 1s 15ms/step - loss: 0.6898 - accuracy: 0.5290 - val_loss: 0.6907 - val_accuracy: 0.5336
# Epoch 19/20
# 73/73 [==============================] - 1s 16ms/step - loss: 0.6896 - accuracy: 0.5294 - val_loss: 0.6907 - val_accuracy: 0.5232
# Epoch 20/20
# 73/73 [==============================] - 1s 14ms/step - loss: 0.6893 - accuracy: 0.5337 - val_loss: 0.6905 - val_accuracy: 0.5198
# Fold 5 Accuracy: 0.5198

# %%
# Convert lists to NumPy arrays for easy averaging
train_accuracies = np.array(train_accuracies)
val_accuracies = np.array(val_accuracies)
train_losses = np.array(train_losses)
val_losses = np.array(val_losses)

# Compute mean accuracy/loss across folds
mean_train_acc = np.mean(train_accuracies, axis=0)
mean_val_acc = np.mean(val_accuracies, axis=0)
mean_train_loss = np.mean(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)

# 🎯 Final mean accuracy across folds
final_accuracy = np.mean(val_accuracies[:, -1])
print(f"\nFinal K-Fold Accuracy: {final_accuracy:.4f}")

# 📊 Plot Accuracy Curves
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(mean_train_acc, label='Train Accuracy')
plt.plot(mean_val_acc, label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Parkinson's QE-RNN - Mean Accuracy Over Folds")
plt.legend()

# 📊 Plot Loss Curves
plt.subplot(1, 2, 2)
plt.plot(mean_train_loss, label='Train Loss')
plt.plot(mean_val_loss, label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Parkinson's QE-RNN - Mean Loss Over Folds")
plt.legend()

plt.show()
# Out:
# Final K-Fold Accuracy: 0.5182

# %%
import pandas as pd
import numpy as np

# Convert lists to numpy arrays
folds = list(range(1, len(train_accuracies) + 1))

# Create DataFrame with results per fold
df_results = pd.DataFrame({
    'Fold': folds,
    'Final Train Accuracy': [train_acc[-1] for train_acc in train_accuracies],
    'Final Validation Accuracy': [val_acc[-1] for val_acc in val_accuracies],
    'Final Train Loss': [train_loss[-1] for train_loss in train_losses],
    'Final Validation Loss': [val_loss[-1] for val_loss in val_losses]
})

# Print results
print("\n📊 K-Fold Cross-Validation Results:\n")
print(df_results)

# Compute summary statistics (mean & std deviation)
df_summary = df_results.describe().loc[['mean', 'std']]
print("\n📌 Summary Statistics (Mean & Std Deviation):\n")
print(df_summary)
# Out:
# 📊 K-Fold Cross-Validation Results:
#
#    Fold  Final Train Accuracy  Final Validation Accuracy  Final Train Loss  \
# 0     1              0.529665                   0.486254          0.689025
# 1     2              0.528375                   0.494845          0.688818
# 2     3              0.527945                   0.541237          0.689366
# 3     4              0.532445                   0.549053          0.688474
# 4     5              0.533734                   0.519793          0.689301
#
#    Final Validation Loss
# 0               0.693922
# 1               0.696503
# 2               0.689259
# 3               0.692947
# 4               0.690544
#
# 📌 Summary Statistics (Mean & Std Deviation):
#
#           Fold  Final Train Accuracy  Final Validation Accuracy  \
# mean  3.000000              0.530433                   0.518237
# std   1.581139              0.002548                   0.027619
#
#       Final Train Loss  Final Validation Loss
# mean          0.688997               0.692635
# std           0.000366               0.002850

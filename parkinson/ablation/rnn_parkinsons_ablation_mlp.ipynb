# %%
import pandas as pd

# Load full quantum features
df = pd.read_csv("final_parkinsons_features.csv")

print(f"✅ Loaded full quantum features: {df.shape[1]} columns.")
# Out:
# ✅ Loaded full quantum features: 22 columns.

# %%
import matplotlib.pyplot as plt

def plot_history(history, title):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    # Accuracy Plot
    axs[0].plot(history.history['accuracy'], label="Train Accuracy")
    axs[0].plot(history.history['val_accuracy'], label="Validation Accuracy")
    axs[0].set_title(f"Model Accuracy - {title}")
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend()

    # Loss Plot
    axs[1].plot(history.history['loss'], label="Train Loss")
    axs[1].plot(history.history['val_loss'], label="Validation Loss")
    axs[1].set_title(f"Model Loss - {title}")
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")
    axs[1].legend()

    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = df.drop(columns=["Subject_ID","Gait_Cycle_Percent","Unnamed: 0"])
df_corr = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature-Label Correlation")
plt.show()

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.layers import BatchNormalization, Dropout

tf.keras.backend.set_floatx('float32')

# Ensure features and labels are correctly extracted
X = df.drop(columns=["label"]).values  # Features
y = df["label"].values  # Labels

# Convert labels to one-hot encoding *before* splitting
y_onehot = tf.keras.utils.to_categorical(y, num_classes=2)

# Split once: train + temp
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.2, stratify=y_onehot, random_state=42)

# Split again: train + val (from temp)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42)

# ✅ Remove MinMaxScaler, keep StandardScaler
scaler = StandardScaler()  # StandardScaler ensures proper feature scaling for PCA
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# Convert to float32 (required for TensorFlow)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
y_train = y_train.astype("float32")
X_val = X_val.astype("float32")

print(f"✅ X_train Labels shape: {y_train.shape}, {y_train.shape}")
print(f"✅ X_val Labels shape: {y_val.shape}, {y_val.shape}")
print(f"✅ X_test Labels shape: {y_test.shape}, {y_test.shape}")
# Out:
# ✅ X_train Labels shape: (2908,), (2908,)
# ✅ X_val Labels shape: (970,), (970,)
# ✅ X_test Labels shape: (970,), (970,)

# %%
import tensorflow as tf
import numpy as np

# Ensure input shape is flat: [samples, features]
assert len(X_train.shape) == 2, "Input should be flat [samples, features] for MLP"

# MLP model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
])

# Compile
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss="binary_crossentropy",
              metrics=["accuracy"])

# Convert labels to 1D if needed
if len(y_train.shape) > 1 and y_train.shape[1] > 1:
    y_train = np.argmax(y_train, axis=1)
    y_val = np.argmax(y_val, axis=1)

# Train
history = model.fit(X_train, y_train,
                    epochs=20,
                    validation_data=(X_val, y_val),
                    batch_size=32,
                    verbose=1)
# Out:
# Epoch 1/20
# 91/91 [==============================] - 1s 8ms/step - loss: 0.7180 - accuracy: 0.4825 - val_loss: 0.7003 - val_accuracy: 0.4907
# Epoch 2/20
# 91/91 [==============================] - 1s 7ms/step - loss: 0.7105 - accuracy: 0.4869 - val_loss: 0.6954 - val_accuracy: 0.5186
# Epoch 3/20
# 91/91 [==============================] - 1s 6ms/step - loss: 0.7067 - accuracy: 0.4852 - val_loss: 0.6927 - val_accuracy: 0.5268
# Epoch 4/20
# 91/91 [==============================] - 0s 5ms/step - loss: 0.7032 - accuracy: 0.4914 - val_loss: 0.6913 - val_accuracy: 0.5227
# Epoch 5/20
# 91/91 [==============================] - 0s 5ms/step - loss: 0.6976 - accuracy: 0.5182 - val_loss: 0.6907 - val_accuracy: 0.5216
# Epoch 6/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6992 - accuracy: 0.5220 - val_loss: 0.6899 - val_accuracy: 0.5330
# Epoch 7/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6986 - accuracy: 0.5058 - val_loss: 0.6897 - val_accuracy: 0.5371
# Epoch 8/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6970 - accuracy: 0.5158 - val_loss: 0.6895 - val_accuracy: 0.5392
# Epoch 9/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6954 - accuracy: 0.5162 - val_loss: 0.6888 - val_accuracy: 0.5361
# Epoch 10/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6930 - accuracy: 0.5279 - val_loss: 0.6884 - val_accuracy: 0.5536
# Epoch 11/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6950 - accuracy: 0.5186 - val_loss: 0.6880 - val_accuracy: 0.5639
# Epoch 12/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 0.5375 - val_loss: 0.6874 - val_accuracy: 0.5577
# Epoch 13/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6930 - accuracy: 0.5186 - val_loss: 0.6870 - val_accuracy: 0.5608
# Epoch 14/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 0.5241 - val_loss: 0.6867 - val_accuracy: 0.5680
# Epoch 15/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6918 - accuracy: 0.5323 - val_loss: 0.6866 - val_accuracy: 0.5701
# Epoch 16/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6914 - accuracy: 0.5275 - val_loss: 0.6864 - val_accuracy: 0.5619
# Epoch 17/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6891 - accuracy: 0.5420 - val_loss: 0.6860 - val_accuracy: 0.5557
# Epoch 18/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6895 - accuracy: 0.5402 - val_loss: 0.6858 - val_accuracy: 0.5619
# Epoch 19/20
# 91/91 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.5502 - val_loss: 0.6858 - val_accuracy: 0.5567
# Epoch 20/20
# 91/91 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.5512 - val_loss: 0.6854 - val_accuracy: 0.5588

# %%
plot_history(history, "QNN Quantum+PCA Reduced Features")

# %%
# ✅ Evaluate
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"QNN Test Accuracy: {test_acc:.4f} | Loss: {test_loss:.4f}")
# Out:
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6868 - accuracy: 0.5474
# QNN Test Accuracy: 0.5474 | Loss: 0.6868

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 🔹 Step 1: Get prediction probabilities
y_pred_probs = model.predict(X_test)

# 🔹 Step 2: Binarize predictions (assuming sigmoid output layer)
y_pred = (y_pred_probs > 0.5).astype(int).flatten()

# 🔹 Step 3: Decode true labels if they're one-hot encoded
if len(y_test.shape) > 1 and y_test.shape[1] > 1:
    y_test = np.argmax(y_test, axis=1)  # convert [0,1] to 1 and [1,0] to 0

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt=".0f", cmap="Blues",
            xticklabels=["Off", "On"], yticklabels=["Off", "On"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - QE-RNN Model")
plt.show()

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# 31/31 [==============================] - 0s 1ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.28      0.37       465
#            1       0.54      0.80      0.65       505
#
#     accuracy                           0.55       970
#    macro avg       0.55      0.54      0.51       970
# weighted avg       0.55      0.55      0.51       970

# %% [markdown]
# # Confidence Check

# %%
import numpy as np

# Get model predictions
y_pred_probs = model.predict(X_test)

# Check confidence distribution
print("Min Confidence:", np.min(y_pred_probs))
print("Max Confidence:", np.max(y_pred_probs))
print("Mean Confidence:", np.mean(y_pred_probs))
# Out:
# 31/31 [==============================] - 0s 1ms/step
# Min Confidence: 0.23200396
# Max Confidence: 0.7648035
# Mean Confidence: 0.52166575

# %%
y_true_qnn = y_test# Convert one-hot labels to class labels
y_pred_qnn = np.argmax(model.predict(X_test), axis=1)
confidences_qnn = np.max(model.predict(X_test), axis=1)

# Convert to numpy arrays if needed
qnn_confidences = np.array(confidences_qnn)  # Replace with your QNN confidence list

plt.figure(figsize=(10, 5))

# QNN Confidence Distribution
plt.subplot(1, 2, 1)
plt.hist(qnn_confidences, bins=20, color='blue', alpha=0.7, edgecolor='black')
plt.title("QNN Confidence Distribution")
plt.xlabel("Confidence Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
# Out:
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step

# %% [markdown]
# # K-Fold

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# Define number of folds
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Store metrics
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []

all_train_acc = []
all_val_acc = []
all_train_loss = []
all_val_loss = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
    print(f"\nTraining Fold {fold+1}/{k}")

    # Split data
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

    # Define MLP model
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, clipvalue=0.5),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])

    # Train model
    history = model.fit(X_train_fold, y_train_fold, 
                        epochs=20, batch_size=32, 
                        validation_data=(X_val_fold, y_val_fold), 
                        verbose=1)

    # Store per-epoch results
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])

    # Evaluate model
    _, accuracy = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    print(f"Fold {fold+1} Accuracy: {accuracy:.4f}")

# Optionally compute average metrics across folds (last epoch)
final_train_acc = [acc[-1] for acc in train_accuracies]
final_val_acc = [acc[-1] for acc in val_accuracies]
final_train_loss = [loss[-1] for loss in train_losses]
final_val_loss = [loss[-1] for loss in val_losses]

print("\n📊 Final K-Fold Results (MLP on Quantum Features):")
print(f"Train Accuracy: {np.mean(final_train_acc):.4f} ± {np.std(final_train_acc):.4f}")
print(f"Val Accuracy:   {np.mean(final_val_acc):.4f} ± {np.std(final_val_acc):.4f}")
print(f"Train Loss:     {np.mean(final_train_loss):.4f} ± {np.std(final_train_loss):.4f}")
print(f"Val Loss:       {np.mean(final_val_loss):.4f} ± {np.std(final_val_loss):.4f}")
# Out:
# Training Fold 1/5
# Epoch 1/20
# 73/73 [==============================] - 1s 9ms/step - loss: 0.7166 - accuracy: 0.5099 - val_loss: 0.7145 - val_accuracy: 0.4674
# Epoch 2/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.7040 - accuracy: 0.5150 - val_loss: 0.7082 - val_accuracy: 0.4691
# Epoch 3/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.7004 - accuracy: 0.5193 - val_loss: 0.7053 - val_accuracy: 0.4691
# Epoch 4/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7023 - accuracy: 0.5202 - val_loss: 0.7020 - val_accuracy: 0.4725
# Epoch 5/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.7027 - accuracy: 0.5013 - val_loss: 0.7002 - val_accuracy: 0.4880
# Epoch 6/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6975 - accuracy: 0.5107 - val_loss: 0.6988 - val_accuracy: 0.4983
# Epoch 7/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6996 - accuracy: 0.5185 - val_loss: 0.6980 - val_accuracy: 0.4897
# Epoch 8/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6987 - accuracy: 0.5116 - val_loss: 0.6969 - val_accuracy: 0.5052
# Epoch 9/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6985 - accuracy: 0.5172 - val_loss: 0.6963 - val_accuracy: 0.5034
# Epoch 10/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5288 - val_loss: 0.6959 - val_accuracy: 0.4914
# Epoch 11/20
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6993 - accuracy: 0.5116 - val_loss: 0.6952 - val_accuracy: 0.4966
# Epoch 12/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6947 - accuracy: 0.5172 - val_loss: 0.6950 - val_accuracy: 0.5069
# Epoch 13/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5279 - val_loss: 0.6945 - val_accuracy: 0.5017
# Epoch 14/20
# 73/73 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.5228 - val_loss: 0.6937 - val_accuracy: 0.5103
# Epoch 15/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.5310 - val_loss: 0.6930 - val_accuracy: 0.5137
# Epoch 16/20
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6925 - accuracy: 0.5288 - val_loss: 0.6931 - val_accuracy: 0.5223
# Epoch 17/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6901 - accuracy: 0.5297 - val_loss: 0.6931 - val_accuracy: 0.5206
# Epoch 18/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6919 - accuracy: 0.5378 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 19/20
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6844 - accuracy: 0.5608 - val_loss: 0.6910 - val_accuracy: 0.5473
# Epoch 19/20
# 73/73 [==============================] - 0s 7ms/step - loss: 0.6887 - accuracy: 0.5423 - val_loss: 0.6907 - val_accuracy: 0.5525
# Epoch 20/20
# 73/73 [==============================] - 0s 6ms/step - loss: 0.6873 - accuracy: 0.5496 - val_loss: 0.6903 - val_accuracy: 0.5508
# Fold 5 Accuracy: 0.5508
#
# 📊 Final K-Fold Results (MLP on Quantum Features):
# Train Accuracy: 0.5419 ± 0.0054
# Val Accuracy:   0.5516 ± 0.0093
# Train Loss:     0.6885 ± 0.0012
# Val Loss:       0.6890 ± 0.0028

# %%
# Convert lists to NumPy arrays for easy averaging
train_accuracies = np.array(train_accuracies)
val_accuracies = np.array(val_accuracies)
train_losses = np.array(train_losses)
val_losses = np.array(val_losses)

# Compute mean accuracy/loss across folds
mean_train_acc = np.mean(train_accuracies, axis=0)
mean_val_acc = np.mean(val_accuracies, axis=0)
mean_train_loss = np.mean(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)

# 🎯 Final mean accuracy across folds
final_accuracy = np.mean(val_accuracies[:, -1])
print(f"\nFinal K-Fold Accuracy: {final_accuracy:.4f}")

# 📊 Plot Accuracy Curves
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(mean_train_acc, label='Train Accuracy')
plt.plot(mean_val_acc, label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Parkinson's QE-RNN - Mean Accuracy Over Folds")
plt.legend()

# 📊 Plot Loss Curves
plt.subplot(1, 2, 2)
plt.plot(mean_train_loss, label='Train Loss')
plt.plot(mean_val_loss, label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Parkinson's QE-RNN - Mean Loss Over Folds")
plt.legend()

plt.show()
# Out:
# Final K-Fold Accuracy: 0.5516

# %%
import pandas as pd
import numpy as np

# Convert lists to numpy arrays
folds = list(range(1, len(train_accuracies) + 1))

# Create DataFrame with results per fold
df_results = pd.DataFrame({
    'Fold': folds,
    'Final Train Accuracy': [train_acc[-1] for train_acc in train_accuracies],
    'Final Validation Accuracy': [val_acc[-1] for val_acc in val_accuracies],
    'Final Train Loss': [train_loss[-1] for train_loss in train_losses],
    'Final Validation Loss': [val_loss[-1] for val_loss in val_losses]
})

# Print results
print("\n📊 K-Fold Cross-Validation Results:\n")
print(df_results)

# Compute summary statistics (mean & std deviation)
df_summary = df_results.describe().loc[['mean', 'std']]
print("\n📌 Summary Statistics (Mean & Std Deviation):\n")
print(df_summary)
# Out:
# 📊 K-Fold Cross-Validation Results:
#
#    Fold  Final Train Accuracy  Final Validation Accuracy  Final Train Loss  \
# 0     1              0.539983                   0.539519          0.688406
# 1     2              0.545572                   0.544674          0.687538
# 2     3              0.540413                   0.556701          0.690520
# 3     4              0.533734                   0.566265          0.688975
# 4     5              0.549635                   0.550775          0.687287
#
#    Final Validation Loss
# 0               0.692674
# 1               0.689917
# 2               0.684526
# 3               0.687374
# 4               0.690339
#
# 📌 Summary Statistics (Mean & Std Deviation):
#
#           Fold  Final Train Accuracy  Final Validation Accuracy  \
# mean  3.000000              0.541867                   0.551587
# std   1.581139              0.006039                   0.010437
#
#       Final Train Loss  Final Validation Loss
# mean          0.688545               0.688966
# std           0.001294               0.003114
